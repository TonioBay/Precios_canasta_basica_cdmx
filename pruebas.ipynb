# %%
import pdfplumber
import pandas as pd
import os
from funciones import tables_extraction
#Extracción de tablas
ruta_pdf = os.path.join('File', 'ano-2024.pdf')

# %%
tables = tables_extraction(ruta_pdf,[720],6.4)
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...

# %%
tables[0].dropna(axis = 0, how = 'all').drop(range(0,3)).reset_index(drop = True)
# Out:
#                     0                           1                2  \
# 0  Jitomate Saladette             $39.90 Chedraui  $54.00 Wal-mart
# 1      Lechuga romana             $21.00 Chedraui  $29.90 Wal-mart
# 2          Papa alpha  $37.50 Comercial\nMexicana  $54.00 Wal-mart
# 3              Pepino             $29.00 Chedraui  $46.90 Wal-mart
# 4        Tomate verde  $46.90 Comercial\nMexicana  $59.00 Wal-mart
# 5   Zanahoria mediana  $17.90 Comercial\nMexicana  $29.90 Wal-mart
#
#                  3                4                           5  \
# 0  $25.00 Ruta\n02  $40.00 Ruta\n08  $40.00 Aragón\n3ra Sección
# 1  $20.00 Ruta\n08  $25.00 Ruta\n02  $20.00 Aragón\n3ra Sección
# 2  $27.00 Ruta\n02  $28.00 Ruta\n08  $25.00 Aragón\n3ra Sección
# 3  $26.00 Ruta\n08  $35.00 Ruta\n02             $32.00 La Dalia
# 4  $20.00 Ruta\n08  $26.00 Ruta\n02             $35.00 La Dalia
# 5  $18.00 Ruta\n08  $28.00 Ruta\n02  $20.00 Aragón\n3ra Sección
#
#                             6 7 8     9
# ...
